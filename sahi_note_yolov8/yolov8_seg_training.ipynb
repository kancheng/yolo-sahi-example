# %%
# !yolo settings runs_dir='/mnt/e/yolov8-sahi/sahi_note_yolov8' datasets_dir='/mnt/e/yolov8-sahi/sahi_note_yolov8/datasets'
# Out:
# 💡 Learn about settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings
# Printing '/home/dl/.config/Ultralytics/settings.yaml'
#
# settings_version: 0.0.4
# datasets_dir: /mnt/e/yolov8-sahi/sahi_note_yolov8/datasets
# weights_dir: weights
# runs_dir: /mnt/e/yolov8-sahi/sahi_note_yolov8
# uuid: 3589e5650137295b0c61bd8c870c979f366c4c527ae7f057afcc08eab842cd02
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true

# %%
# !yolo segment train data="coco8-seg.yaml" model="yolov8n-seg.pt" epochs=100 imgsz=640 agnostic_nms=true save=True save_txt=True
# Out:
# Ultralytics YOLOv8.2.77 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...
